# %% [markdown]
# A Series is a one dimensional labele array capable of holding any data type. The axis labels are collectively called the index.
#
# Key Data Structures in Pandas
# -> Series
# -> DataFrame

# %%
import numpy as np
import pandas as pd

s=pd.Series([1,2,3,4,"ayush"],index=['a','b','c','d','e'])
print(s)
# Out:
# a        1
# b        2
# c        3
# d        4
# e    ayush
# dtype: object

# %%
import numpy as np
import pandas as pd

y=pd.Series([1,2,3,4,"ayush"])
print(y)
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4    ayush
# dtype: object

# %% [markdown]
# Data Frames is the twwo dimentional dataStructure.
# Syntax for dataFrames:
# pd.DataFrame([],column=[],index=[])

# %% [markdown]
# Methods to read csv file in pandas

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()

# Get the name of the uploaded file
file_name = next(iter(uploaded))

df = pd.read_csv(file_name)
df.head(40)
df.tail()
#df.info() #shows memory
df.describe()
# Out:
#      <input type="file" id="files-89bcd7f9-1548-4172-8166-bfe5188c2023" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-89bcd7f9-1548-4172-8166-bfe5188c2023">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# There are many different extentions file can we used - parquet, csv, excel file etc.

# %%
#Accessing Data using pandas
# .head() to see the first 5 columns of the file
#  display(file_name)
# .tail() to see the last 5 columns
# .sample(number of column you want to see, random_State=1)
# .loc[#rows,#columns]
#  .loc[0:5,[0,2]] or .loc[:,[0,2,3,4]]
# we can modify the values in a csv file using loc
# .loc[row number,cloumn name]=desired number
df
# Out:
#    ID   Name  Age Department  CGPA
# 0   1   Amit   22        CSE   8.5
# 1   2  Priya   24         IT   9.1
# 2   3  Rahul   21        ECE   7.8
# 3   4  Sneha   23        CSE   8.9
# 4   5  Arjun   25         ME   7.5

# %% [markdown]
# .loc label (naam) se select karta hai, aur .iloc index number (position) se select karta hai.

# %%
#.sort_values([column_name],ascending=[False])
#.sort_values([a,b],ascending=[0,1])
#

# %%
df['house']="Red"
dg=df.drop(columns=['Age']) #to drop a file
df
dg=df.drop(columns=['Age'],inplace=True) #to drop a file
df
# Out:
#    ID   Name Department  CGPA house
# 0   1   Amit        CSE   8.5   Red
# 1   2  Priya         IT   9.1   Red
# 2   3  Rahul        ECE   7.8   Red
# 3   4  Sneha        CSE   8.9   Red
# 4   5  Arjun         ME   7.5   Red

# %%
df[df['Name']=='Amit']['Department'].value_counts()
# Out:
# Department
# CSE    1
# Name: count, dtype: int64

# %%
df.groupby('Department')['CGPA'].mean()
# Out:
# Department
# CSE    8.7
# ECE    7.8
# IT     9.1
# ME     7.5
# Name: CGPA, dtype: float64
